# %%
import torch
from mmdet.apis import inference_detector, init_detector, show_result_pyplot

# 根据colab状态设置device
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
# 选择模型对应的配置文件
config = '../work_dirs/mask_rcnn_r50_fpn_1x_material/mask_rcnn_r50_fpn_1x_material.py'
# 选择下载好的checkpoint
checkpoint = '../work_dirs/mask_rcnn_r50_fpn_1x_material/epoch_4.pth'
# 初始化模型
model = init_detector(config, checkpoint, device=device)
img = 'D:/wolftail/repos/datasets/material_papers/img/0b9371d6eefc41ddb4c7b183035bef8d_2.png'
result = inference_detector(model, img)
import cv2
model.show_result(
    img,
    result,
    score_thr=0.9,
    show=True,
    win_name='result',
    bbox_color=None,
    text_color=(200, 200, 200),
    mask_color=None)
# Out:
# load checkpoint from local path: ../work_dirs/mask_rcnn_r50_fpn_1x_material/epoch_4.pth
# C:\Users\wolftail\AppData\Roaming\Python\Python37\site-packages\mmdet\datasets\utils.py:70: UserWarning: "ImageToTensor" pipeline is replaced by "DefaultFormatBundle" for batch inference. It is recommended to manually replace it in the test data pipeline in your config file.
#   'data pipeline in your config file.', UserWarning)
